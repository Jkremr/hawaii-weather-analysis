# %%
import pandas as pd
import numpy as np
import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy import MetaData
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Numeric, Date, DECIMAL, ForeignKey
from sqlalchemy.orm import Session

# %%
# Import data into data frames and rename columns in preparation for storage.
measures = pd.read_csv('hawaii_measurements.csv', names=('station_name', 'date', 'precipitation', 'temperature'), header=0, parse_dates=[1])
stations = pd.read_csv('hawaii_stations.csv', names=('station_name', 'location_name', 'latitude', 'longitude', 'elevation'), header=0)

# %%
measures.head()
# Out:
#   station_name       date  precipitation  temperature
# 0  USC00519397 2010-01-01           0.08           65
# 1  USC00519397 2010-01-02           0.00           63
# 2  USC00519397 2010-01-03           0.00           74
# 3  USC00519397 2010-01-04           0.00           76
# 4  USC00519397 2010-01-06            NaN           73

# %%
measures.dtypes
# Out:
# station_name             object
# date             datetime64[ns]
# precipitation           float64
# temperature               int64
# dtype: object

# %%
# There are 1,447 incomplete cases in "measures" due to NaN values in measures['prcp'].

measures.isnull().sum()
# Out:
# station_name        0
# date                0
# precipitation    1447
# temperature         0
# dtype: int64

# %%
# There are no NaN values in "stations"

stations
# Out:
#   station_name                           location_name  latitude  longitude  \
# 0  USC00519397                    WAIKIKI 717.2, HI US  21.27160 -157.81680
# 1  USC00513117                    KANEOHE 838.1, HI US  21.42340 -157.80150
# 2  USC00514830  KUALOA RANCH HEADQUARTERS 886.9, HI US  21.52130 -157.83740
# 3  USC00517948                       PEARL CITY, HI US  21.39340 -157.97510
# 4  USC00518838              UPPER WAHIAWA 874.3, HI US  21.49920 -158.01110
# 5  USC00519523      WAIMANALO EXPERIMENTAL FARM, HI US  21.33556 -157.71139
# 6  USC00519281                     WAIHEE 837.5, HI US  21.45167 -157.84889
# 7  USC00511918       HONOLULU OBSERVATORY 702.2, HI US  21.31520 -157.99920
# 8  USC00516128            MANOA LYON ARBO 785.2, HI US  21.33310 -157.80250
#
#    elevation
# 0        3.0
# 1       14.6
# 2        7.0
# 3       11.9
# 4      306.6
# 5       19.5
# 6       32.9
# 7        0.9
# 8      152.4

# %%
# If complete cases are needed, Pandas' .dropna() can be used to elimate all rows with NaNs.
# Here a "clean" copy of the data is saved to a new CSV.

measures_clean = measures.dropna(axis=0)
measures_clean.to_csv("hawaii_measurements_clean.csv")

# %%
# Create engine and connection to SQLite.

engine = create_engine("sqlite:///hawaii_weather.sqlite")
conn = engine.connect()

# %%
base = declarative_base()

# %%
class station(base):
    __tablename__ = 'station'
    
    station_name = Column(String(255), primary_key=True)
    location_name = Column(String(255))
    latitude = Column(Numeric)
    longitude = Column(Numeric)
    elevation = Column(Numeric)
    
    def __repr__(self):
        return '<station(%r, %r)>' % (self.station_name, self.location_name)

class measurement(base):
    __tablename__ = 'measurement'
    
    id = Column(Integer, primary_key=True)
    station_name = Column(String(255), ForeignKey('station.station_name'))
    date = Column(Date)
#     precipitation = Column(Numeric, nullable=True)
    precipitation = Column(String(255), nullable=True)
    temperature = Column(Numeric, nullable=True)
    
    def __repr__(self):
        return "<measure(%r, %r)>" % (self.station_name, self.date)

# %%
station.__table__
# Out:
# Table('station', MetaData(bind=None), Column('station_name', String(length=255), table=<station>, primary_key=True, nullable=False), Column('location_name', String(length=255), table=<station>), Column('latitude', Numeric(), table=<station>), Column('longitude', Numeric(), table=<station>), Column('elevation', Numeric(), table=<station>), schema=None)

# %%
measurement(station_name = 'jake', date = '2008-01-01', precipitation = 12, temperature = 55)
# Out:
# <measure('jake', '2008-01-01')>

# %%
measurement.__table__
# Out:
# Table('measurement', MetaData(bind=None), Column('id', Integer(), table=<measurement>, primary_key=True, nullable=False), Column('station_name', String(length=255), ForeignKey('station.station_name'), table=<measurement>), Column('date', Date(), table=<measurement>), Column('precipitation', String(length=255), table=<measurement>), Column('temperature', Numeric(), table=<measurement>), schema=None)

# %%
base.metadata.create_all(engine)

# %%
stations_dict = stations.to_dict(orient='records')
stations_dict[0]
# Out:
# {'elevation': 3.0,
#  'latitude': 21.2716,
#  'location_name': 'WAIKIKI 717.2, HI US',
#  'longitude': -157.8168,
#  'station_name': 'USC00519397'}

# %%
measures_dict = measures.to_dict(orient='records')
measures_dict
# Out:
# [{'date': Timestamp('2010-01-01 00:00:00'),
#   'precipitation': 0.08,
#   'station_name': 'USC00519397',
#   'temperature': 65},
#  {'date': Timestamp('2010-01-02 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 63},
#  {'date': Timestamp('2010-01-03 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2010-01-04 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-01-06 00:00:00'),
#   'precipitation': nan,
#   'station_name': 'USC00519397',
#   'temperature': 73},
#  {'date': Timestamp('2010-01-07 00:00:00'),
#   'precipitation': 0.06,
#   'station_name': 'USC00519397',
#   'temperature': 70},
#  {'date': Timestamp('2010-01-08 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 64},
#  {'date': Timestamp('2010-01-09 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 68},
#  {'date': Timestamp('2010-01-10 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 73},
#  {'date': Timestamp('2010-01-11 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 64},
#  {'date': Timestamp('2010-01-12 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 61},
#  {'date': Timestamp('2010-01-14 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 66},
#  {'date': Timestamp('2010-01-15 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 65},
#  {'date': Timestamp('2010-01-16 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 68},
#  {'date': Timestamp('2010-01-17 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 64},
#  {'date': Timestamp('2010-01-18 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 72},
#  {'date': Timestamp('2010-01-19 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 66},
#  {'date': Timestamp('2010-01-20 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 66},
#  {'date': Timestamp('2010-01-21 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 69},
#  {'date': Timestamp('2010-01-22 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 67},
#  {'date': Timestamp('2010-01-23 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 67},
#  {'date': Timestamp('2010-01-24 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 71},
#  {'date': Timestamp('2010-01-25 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 67},
#  {'date': Timestamp('2010-01-26 00:00:00'),
#   'precipitation': 0.04,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-01-27 00:00:00'),
#   'precipitation': 0.12,
#   'station_name': 'USC00519397',
#   'temperature': 68},
#  {'date': Timestamp('2010-01-28 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 72},
#  {'date': Timestamp('2010-01-30 00:00:00'),
#   'precipitation': nan,
#   'station_name': 'USC00519397',
#   'temperature': 70},
#  {'date': Timestamp('2010-01-31 00:00:00'),
#   'precipitation': 0.03,
#   'station_name': 'USC00519397',
#   'temperature': 67},
#  {'date': Timestamp('2010-02-01 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 66},
#  {'date': Timestamp('2010-02-03 00:00:00'),
#   'precipitation': nan,
#   'station_name': 'USC00519397',
#   'temperature': 67},
#  {'date': Timestamp('2010-02-04 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 69},
#  {'date': Timestamp('2010-02-05 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 67},
#  {'date': Timestamp('2010-02-06 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 67},
#  {'date': Timestamp('2010-02-07 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 64},
#  {'date': Timestamp('2010-02-08 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 69},
#  {'date': Timestamp('2010-02-09 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 73},
#  {'date': Timestamp('2010-02-11 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 73},
#  {'date': Timestamp('2010-02-12 00:00:00'),
#   'precipitation': 0.02,
#   'station_name': 'USC00519397',
#   'temperature': 69},
#  {'date': Timestamp('2010-02-13 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 69},
#  {'date': Timestamp('2010-02-14 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 69},
#  {'date': Timestamp('2010-02-15 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 71},
#  {'date': Timestamp('2010-02-16 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 61},
#  {'date': Timestamp('2010-02-17 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 69},
#  {'date': Timestamp('2010-02-19 00:00:00'),
#   'precipitation': nan,
#   'station_name': 'USC00519397',
#   'temperature': 63},
#  {'date': Timestamp('2010-02-20 00:00:00'),
#   'precipitation': 0.03,
#   'station_name': 'USC00519397',
#   'temperature': 64},
#  {'date': Timestamp('2010-02-21 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 65},
#  {'date': Timestamp('2010-02-22 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 67},
#  {'date': Timestamp('2010-02-23 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 68},
#  {'date': Timestamp('2010-02-24 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 65},
#  {'date': Timestamp('2010-02-25 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-02-26 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2010-02-28 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 66},
#  {'date': Timestamp('2010-03-01 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 70},
#  {'date': Timestamp('2010-03-02 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 72},
#  {'date': Timestamp('2010-03-03 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 73},
#  {'date': Timestamp('2010-03-04 00:00:00'),
#   'precipitation': 0.12,
#   'station_name': 'USC00519397',
#   'temperature': 70},
#  {'date': Timestamp('2010-03-05 00:00:00'),
#   'precipitation': 0.08,
#   'station_name': 'USC00519397',
#   'temperature': 71},
#  {'date': Timestamp('2010-03-06 00:00:00'),
#   'precipitation': 0.03,
#   'station_name': 'USC00519397',
#   'temperature': 72},
#  {'date': Timestamp('2010-03-07 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 72},
#  {'date': Timestamp('2010-03-08 00:00:00'),
#   'precipitation': 0.43,
#   'station_name': 'USC00519397',
#   'temperature': 69},
#  {'date': Timestamp('2010-03-09 00:00:00'),
#   'precipitation': 0.06,
#   'station_name': 'USC00519397',
#   'temperature': 70},
#  {'date': Timestamp('2010-03-11 00:00:00'),
#   'precipitation': nan,
#   'station_name': 'USC00519397',
#   'temperature': 73},
#  {'date': Timestamp('2010-03-12 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 72},
#  {'date': Timestamp('2010-03-13 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 73},
#  {'date': Timestamp('2010-03-14 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 70},
#  {'date': Timestamp('2010-03-15 00:00:00'),
#   'precipitation': 0.06,
#   'station_name': 'USC00519397',
#   'temperature': 71},
#  {'date': Timestamp('2010-03-17 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 68},
#  {'date': Timestamp('2010-03-18 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 70},
#  {'date': Timestamp('2010-03-21 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 72},
#  {'date': Timestamp('2010-03-22 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 69},
#  {'date': Timestamp('2010-03-23 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 68},
#  {'date': Timestamp('2010-03-24 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2010-03-26 00:00:00'),
#   'precipitation': nan,
#   'station_name': 'USC00519397',
#   'temperature': 72},
#  {'date': Timestamp('2010-03-27 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 72},
#  {'date': Timestamp('2010-03-28 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 73},
#  {'date': Timestamp('2010-03-29 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2010-03-30 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 73},
#  {'date': Timestamp('2010-03-31 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 73},
#  {'date': Timestamp('2010-04-01 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2010-04-02 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2010-04-03 00:00:00'),
#   'precipitation': 0.17,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2010-04-04 00:00:00'),
#   'precipitation': 0.15,
#   'station_name': 'USC00519397',
#   'temperature': 71},
#  {'date': Timestamp('2010-04-05 00:00:00'),
#   'precipitation': 0.27,
#   'station_name': 'USC00519397',
#   'temperature': 72},
#  {'date': Timestamp('2010-04-06 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2010-04-08 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2010-04-09 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2010-04-10 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2010-04-11 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 73},
#  {'date': Timestamp('2010-04-12 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 73},
#  {'date': Timestamp('2010-04-13 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 71},
#  {'date': Timestamp('2010-04-15 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 71},
#  {'date': Timestamp('2010-04-16 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 68},
#  {'date': Timestamp('2010-04-17 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 70},
#  {'date': Timestamp('2010-04-18 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 71},
#  {'date': Timestamp('2010-04-19 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2010-04-20 00:00:00'),
#   'precipitation': 0.04,
#   'station_name': 'USC00519397',
#   'temperature': 71},
#  {'date': Timestamp('2010-04-21 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2010-04-22 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-04-23 00:00:00'),
#   'precipitation': 0.02,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2010-04-24 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2010-04-25 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-04-26 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-04-28 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-04-30 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-05-01 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-05-02 00:00:00'),
#   'precipitation': 0.03,
#   'station_name': 'USC00519397',
#   'temperature': 73},
#  {'date': Timestamp('2010-05-03 00:00:00'),
#   'precipitation': 0.2,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2010-05-04 00:00:00'),
#   'precipitation': 0.08,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-05-05 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-05-06 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 80},
#  {'date': Timestamp('2010-05-07 00:00:00'),
#   'precipitation': 0.05,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2010-05-08 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-05-09 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-05-10 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-05-11 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-05-13 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-05-14 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-05-15 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2010-05-16 00:00:00'),
#   'precipitation': 0.03,
#   'station_name': 'USC00519397',
#   'temperature': 73},
#  {'date': Timestamp('2010-05-17 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-05-18 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-05-19 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-05-21 00:00:00'),
#   'precipitation': nan,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-05-22 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-05-23 00:00:00'),
#   'precipitation': 0.05,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2010-05-24 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-05-25 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-05-26 00:00:00'),
#   'precipitation': 0.02,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-05-27 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-05-28 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2010-05-29 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-05-30 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-05-31 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-06-01 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-06-02 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-06-03 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-06-04 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-06-05 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-06-06 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-06-07 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-06-08 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-06-09 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-06-10 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 79},
#  {'date': Timestamp('2010-06-11 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-06-12 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-06-13 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-06-14 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-06-15 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-06-16 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-06-17 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-06-18 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-06-19 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 82},
#  {'date': Timestamp('2010-06-20 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-06-21 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-06-22 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-06-23 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-06-24 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-06-25 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-06-26 00:00:00'),
#   'precipitation': 0.02,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-06-27 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-06-28 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-06-29 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-06-30 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-07-01 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2010-07-02 00:00:00'),
#   'precipitation': 0.05,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-07-03 00:00:00'),
#   'precipitation': 0.09,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-07-04 00:00:00'),
#   'precipitation': 0.05,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-07-05 00:00:00'),
#   'precipitation': 0.06,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-07-06 00:00:00'),
#   'precipitation': 0.08,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-07-07 00:00:00'),
#   'precipitation': 0.08,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2010-07-08 00:00:00'),
#   'precipitation': 0.03,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-07-09 00:00:00'),
#   'precipitation': 0.06,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2010-07-10 00:00:00'),
#   'precipitation': 0.09,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-07-11 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-07-12 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-07-13 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 80},
#  {'date': Timestamp('2010-07-16 00:00:00'),
#   'precipitation': nan,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-07-17 00:00:00'),
#   'precipitation': 0.02,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-07-18 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-07-19 00:00:00'),
#   'precipitation': 0.04,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-07-21 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 80},
#  {'date': Timestamp('2010-07-22 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-07-24 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 80},
#  {'date': Timestamp('2010-07-25 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 79},
#  {'date': Timestamp('2010-07-26 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-07-27 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 79},
#  {'date': Timestamp('2010-07-28 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-07-29 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 79},
#  {'date': Timestamp('2010-07-30 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-07-31 00:00:00'),
#   'precipitation': 0.02,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-08-01 00:00:00'),
#   'precipitation': 0.04,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-08-02 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-08-03 00:00:00'),
#   'precipitation': 0.02,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-08-04 00:00:00'),
#   'precipitation': 0.07,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-08-05 00:00:00'),
#   'precipitation': 0.08,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2010-08-06 00:00:00'),
#   'precipitation': 0.03,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2010-08-07 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 80},
#  {'date': Timestamp('2010-08-08 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-08-09 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-08-10 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-08-11 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-08-12 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-08-13 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-08-14 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-08-15 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-08-16 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-08-17 00:00:00'),
#   'precipitation': 0.05,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2010-08-18 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-08-19 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 79},
#  {'date': Timestamp('2010-08-20 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 79},
#  {'date': Timestamp('2010-08-21 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 79},
#  {'date': Timestamp('2010-08-22 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2010-08-23 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 87},
#  {'date': Timestamp('2010-08-24 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-08-25 00:00:00'),
#   'precipitation': 0.04,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-08-26 00:00:00'),
#   'precipitation': 0.03,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-08-27 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-08-28 00:00:00'),
#   'precipitation': 0.04,
#   'station_name': 'USC00519397',
#   'temperature': 79},
#  {'date': Timestamp('2010-08-29 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-08-30 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-08-31 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 80},
#  {'date': Timestamp('2010-09-01 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-09-02 00:00:00'),
#   'precipitation': 0.02,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-09-03 00:00:00'),
#   'precipitation': 0.04,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-09-04 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-09-05 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-09-06 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-09-07 00:00:00'),
#   'precipitation': 0.06,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-09-08 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-09-09 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-09-10 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-09-11 00:00:00'),
#   'precipitation': 0.05,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-09-12 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2010-09-13 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-09-14 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 79},
#  {'date': Timestamp('2010-09-15 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-09-16 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 79},
#  {'date': Timestamp('2010-09-17 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-09-19 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-09-20 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-09-21 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 79},
#  {'date': Timestamp('2010-09-22 00:00:00'),
#   'precipitation': 0.04,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-09-23 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-09-24 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-09-25 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 79},
#  {'date': Timestamp('2010-09-26 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2010-09-27 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2010-09-28 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2010-09-29 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-09-30 00:00:00'),
#   'precipitation': 0.57,
#   'station_name': 'USC00519397',
#   'temperature': 73},
#  {'date': Timestamp('2010-10-01 00:00:00'),
#   'precipitation': 0.31,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-10-02 00:00:00'),
#   'precipitation': 0.03,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-10-03 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-10-04 00:00:00'),
#   'precipitation': 0.06,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-10-05 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 80},
#  {'date': Timestamp('2010-10-06 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 79},
#  {'date': Timestamp('2010-10-07 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 79},
#  {'date': Timestamp('2010-10-08 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-10-09 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-10-10 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-10-11 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-10-12 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 79},
#  {'date': Timestamp('2010-10-13 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-10-15 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-10-16 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-10-17 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-10-18 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-10-19 00:00:00'),
#   'precipitation': 0.07,
#   'station_name': 'USC00519397',
#   'temperature': 72},
#  {'date': Timestamp('2010-10-20 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2010-10-21 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 80},
#  {'date': Timestamp('2010-10-22 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-10-23 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2010-10-24 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-10-25 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-10-26 00:00:00'),
#   'precipitation': 0.07,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-10-27 00:00:00'),
#   'precipitation': 0.05,
#   'station_name': 'USC00519397',
#   'temperature': 79},
#  {'date': Timestamp('2010-10-28 00:00:00'),
#   'precipitation': 0.06,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-10-29 00:00:00'),
#   'precipitation': 0.03,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2010-10-30 00:00:00'),
#   'precipitation': 0.02,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-10-31 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-11-01 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2010-11-02 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 73},
#  {'date': Timestamp('2010-11-04 00:00:00'),
#   'precipitation': nan,
#   'station_name': 'USC00519397',
#   'temperature': 73},
#  {'date': Timestamp('2010-11-05 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-11-06 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-11-07 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-11-08 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-11-09 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 73},
#  {'date': Timestamp('2010-11-10 00:00:00'),
#   'precipitation': 0.23,
#   'station_name': 'USC00519397',
#   'temperature': 73},
#  {'date': Timestamp('2010-11-11 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-11-12 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-11-13 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-11-16 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 73},
#  {'date': Timestamp('2010-11-17 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 73},
#  {'date': Timestamp('2010-11-19 00:00:00'),
#   'precipitation': nan,
#   'station_name': 'USC00519397',
#   'temperature': 72},
#  {'date': Timestamp('2010-11-20 00:00:00'),
#   'precipitation': 0.03,
#   'station_name': 'USC00519397',
#   'temperature': 69},
#  {'date': Timestamp('2010-11-21 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 69},
#  {'date': Timestamp('2010-11-22 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 68},
#  {'date': Timestamp('2010-11-23 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 69},
#  {'date': Timestamp('2010-11-24 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-11-25 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-11-27 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2010-11-28 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2010-11-29 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 69},
#  {'date': Timestamp('2010-11-30 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2010-12-01 00:00:00'),
#   'precipitation': 0.04,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2010-12-03 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2010-12-04 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2010-12-06 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 64},
#  {'date': Timestamp('2010-12-07 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 64},
#  {'date': Timestamp('2010-12-08 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 67},
#  {'date': Timestamp('2010-12-09 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2010-12-10 00:00:00'),
#   'precipitation': 1.58,
#   'station_name': 'USC00519397',
#   'temperature': 66},
#  {'date': Timestamp('2010-12-11 00:00:00'),
#   'precipitation': 0.77,
#   'station_name': 'USC00519397',
#   'temperature': 69},
#  {'date': Timestamp('2010-12-12 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 68},
#  {'date': Timestamp('2010-12-13 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 68},
#  {'date': Timestamp('2010-12-14 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 71},
#  {'date': Timestamp('2010-12-15 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2010-12-16 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 67},
#  {'date': Timestamp('2010-12-17 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 66},
#  {'date': Timestamp('2010-12-18 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 69},
#  {'date': Timestamp('2010-12-19 00:00:00'),
#   'precipitation': 1.4,
#   'station_name': 'USC00519397',
#   'temperature': 71},
#  {'date': Timestamp('2010-12-23 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 70},
#  {'date': Timestamp('2010-12-24 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 70},
#  {'date': Timestamp('2010-12-26 00:00:00'),
#   'precipitation': nan,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2010-12-27 00:00:00'),
#   'precipitation': 0.13,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2010-12-28 00:00:00'),
#   'precipitation': 0.55,
#   'station_name': 'USC00519397',
#   'temperature': 71},
#  {'date': Timestamp('2010-12-29 00:00:00'),
#   'precipitation': 0.06,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2010-12-30 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2010-12-31 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 72},
#  {'date': Timestamp('2011-01-01 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 69},
#  {'date': Timestamp('2011-01-02 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 72},
#  {'date': Timestamp('2011-01-03 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2011-01-04 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 73},
#  {'date': Timestamp('2011-01-05 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 64},
#  {'date': Timestamp('2011-01-06 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 65},
#  {'date': Timestamp('2011-01-07 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 68},
#  {'date': Timestamp('2011-01-08 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 62},
#  {'date': Timestamp('2011-01-09 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 58},
#  {'date': Timestamp('2011-01-10 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 73},
#  {'date': Timestamp('2011-01-11 00:00:00'),
#   'precipitation': 0.09,
#   'station_name': 'USC00519397',
#   'temperature': 60},
#  {'date': Timestamp('2011-01-13 00:00:00'),
#   'precipitation': nan,
#   'station_name': 'USC00519397',
#   'temperature': 68},
#  {'date': Timestamp('2011-01-14 00:00:00'),
#   'precipitation': 0.03,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2011-01-15 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 68},
#  {'date': Timestamp('2011-01-16 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 66},
#  {'date': Timestamp('2011-01-17 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 64},
#  {'date': Timestamp('2011-01-18 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 64},
#  {'date': Timestamp('2011-01-19 00:00:00'),
#   'precipitation': 0.03,
#   'station_name': 'USC00519397',
#   'temperature': 64},
#  {'date': Timestamp('2011-01-20 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2011-01-21 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2011-01-22 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 68},
#  {'date': Timestamp('2011-01-23 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 68},
#  {'date': Timestamp('2011-01-24 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 72},
#  {'date': Timestamp('2011-01-25 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 63},
#  {'date': Timestamp('2011-01-27 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 68},
#  {'date': Timestamp('2011-01-28 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2011-01-29 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 65},
#  {'date': Timestamp('2011-01-30 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 64},
#  {'date': Timestamp('2011-01-31 00:00:00'),
#   'precipitation': 0.22,
#   'station_name': 'USC00519397',
#   'temperature': 68},
#  {'date': Timestamp('2011-02-01 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 68},
#  {'date': Timestamp('2011-02-02 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 66},
#  {'date': Timestamp('2011-02-03 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 67},
#  {'date': Timestamp('2011-02-04 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 64},
#  {'date': Timestamp('2011-02-05 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 65},
#  {'date': Timestamp('2011-02-06 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2011-02-07 00:00:00'),
#   'precipitation': 1.29,
#   'station_name': 'USC00519397',
#   'temperature': 68},
#  {'date': Timestamp('2011-02-08 00:00:00'),
#   'precipitation': 1.3,
#   'station_name': 'USC00519397',
#   'temperature': 71},
#  {'date': Timestamp('2011-02-09 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 71},
#  {'date': Timestamp('2011-02-10 00:00:00'),
#   'precipitation': 0.29,
#   'station_name': 'USC00519397',
#   'temperature': 71},
#  {'date': Timestamp('2011-02-12 00:00:00'),
#   'precipitation': nan,
#   'station_name': 'USC00519397',
#   'temperature': 68},
#  {'date': Timestamp('2011-02-13 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 68},
#  {'date': Timestamp('2011-02-14 00:00:00'),
#   'precipitation': 0.04,
#   'station_name': 'USC00519397',
#   'temperature': 72},
#  {'date': Timestamp('2011-02-15 00:00:00'),
#   'precipitation': 0.05,
#   'station_name': 'USC00519397',
#   'temperature': 70},
#  {'date': Timestamp('2011-02-16 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2011-02-19 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 67},
#  {'date': Timestamp('2011-02-20 00:00:00'),
#   'precipitation': 1.72,
#   'station_name': 'USC00519397',
#   'temperature': 71},
#  {'date': Timestamp('2011-02-21 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 71},
#  {'date': Timestamp('2011-02-22 00:00:00'),
#   'precipitation': 0.82,
#   'station_name': 'USC00519397',
#   'temperature': 71},
#  {'date': Timestamp('2011-02-23 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2011-02-24 00:00:00'),
#   'precipitation': 0.2,
#   'station_name': 'USC00519397',
#   'temperature': 68},
#  {'date': Timestamp('2011-02-25 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 71},
#  {'date': Timestamp('2011-02-26 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 69},
#  {'date': Timestamp('2011-02-27 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 69},
#  {'date': Timestamp('2011-02-28 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 68},
#  {'date': Timestamp('2011-03-01 00:00:00'),
#   'precipitation': 0.1,
#   'station_name': 'USC00519397',
#   'temperature': 68},
#  {'date': Timestamp('2011-03-02 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 72},
#  {'date': Timestamp('2011-03-03 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2011-03-04 00:00:00'),
#   'precipitation': 0.88,
#   'station_name': 'USC00519397',
#   'temperature': 72},
#  {'date': Timestamp('2011-03-05 00:00:00'),
#   'precipitation': 0.4,
#   'station_name': 'USC00519397',
#   'temperature': 69},
#  {'date': Timestamp('2011-03-06 00:00:00'),
# ...
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-07-19 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2012-07-20 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-07-21 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2012-07-22 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2012-07-23 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 79},
#  {'date': Timestamp('2012-07-24 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-07-25 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-07-26 00:00:00'),
#   'precipitation': 0.02,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-07-27 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-07-28 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-07-29 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 73},
#  {'date': Timestamp('2012-07-30 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-07-31 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-08-01 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 79},
#  {'date': Timestamp('2012-08-02 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-08-03 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-08-04 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-08-05 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-08-06 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-08-07 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-08-08 00:00:00'),
#   'precipitation': 0.02,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-08-09 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-08-10 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2012-08-11 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2012-08-12 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-08-13 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-08-14 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-08-15 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 79},
#  {'date': Timestamp('2012-08-16 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-08-17 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-08-18 00:00:00'),
#   'precipitation': nan,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-08-19 00:00:00'),
#   'precipitation': nan,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2012-08-20 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 79},
#  {'date': Timestamp('2012-08-21 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-08-22 00:00:00'),
#   'precipitation': 0.03,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-08-23 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-08-24 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-08-25 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-08-26 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-08-27 00:00:00'),
#   'precipitation': 0.02,
#   'station_name': 'USC00519397',
#   'temperature': 73},
#  {'date': Timestamp('2012-08-28 00:00:00'),
#   'precipitation': 1.0,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2012-08-29 00:00:00'),
#   'precipitation': 0.02,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-08-30 00:00:00'),
#   'precipitation': 0.04,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-08-31 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-09-01 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-09-02 00:00:00'),
#   'precipitation': 0.04,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2012-09-03 00:00:00'),
#   'precipitation': 0.06,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-09-04 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-09-05 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2012-09-06 00:00:00'),
#   'precipitation': 0.04,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-09-07 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2012-09-08 00:00:00'),
#   'precipitation': 0.06,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-09-09 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2012-09-10 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-09-11 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-09-12 00:00:00'),
#   'precipitation': 0.02,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2012-09-13 00:00:00'),
#   'precipitation': 0.05,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2012-09-14 00:00:00'),
#   'precipitation': 0.04,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-09-15 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-09-16 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-09-17 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-09-18 00:00:00'),
#   'precipitation': 0.06,
#   'station_name': 'USC00519397',
#   'temperature': 71},
#  {'date': Timestamp('2012-09-19 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2012-09-20 00:00:00'),
#   'precipitation': 0.07,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2012-09-21 00:00:00'),
#   'precipitation': 0.08,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-09-22 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-09-23 00:00:00'),
#   'precipitation': 0.04,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2012-09-24 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-09-25 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2012-09-26 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2012-09-27 00:00:00'),
#   'precipitation': 0.02,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-09-28 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-09-29 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-09-30 00:00:00'),
#   'precipitation': 0.02,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2012-10-01 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-10-02 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2012-10-03 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2012-10-04 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-10-05 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 73},
#  {'date': Timestamp('2012-10-06 00:00:00'),
#   'precipitation': 0.03,
#   'station_name': 'USC00519397',
#   'temperature': 73},
#  {'date': Timestamp('2012-10-07 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2012-10-08 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-10-09 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2012-10-10 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2012-10-11 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 80},
#  {'date': Timestamp('2012-10-12 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-10-13 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 79},
#  {'date': Timestamp('2012-10-14 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-10-15 00:00:00'),
#   'precipitation': 0.02,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-10-16 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-10-17 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 72},
#  {'date': Timestamp('2012-10-18 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2012-10-19 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-10-20 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-10-21 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-10-22 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2012-10-23 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-10-24 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-10-25 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2012-10-26 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2012-10-27 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2012-10-28 00:00:00'),
#   'precipitation': 0.02,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-10-29 00:00:00'),
#   'precipitation': 0.04,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-10-30 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2012-10-31 00:00:00'),
#   'precipitation': 0.02,
#   'station_name': 'USC00519397',
#   'temperature': 78},
#  {'date': Timestamp('2012-11-01 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 71},
#  {'date': Timestamp('2012-11-02 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 70},
#  {'date': Timestamp('2012-11-03 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2012-11-04 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 71},
#  {'date': Timestamp('2012-11-05 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 69},
#  {'date': Timestamp('2012-11-06 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2012-11-07 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-11-08 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-11-09 00:00:00'),
#   'precipitation': 0.03,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2012-11-10 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2012-11-11 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2012-11-12 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-11-13 00:00:00'),
#   'precipitation': 0.06,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-11-14 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 77},
#  {'date': Timestamp('2012-11-15 00:00:00'),
#   'precipitation': 0.08,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2012-11-16 00:00:00'),
#   'precipitation': 0.03,
#   'station_name': 'USC00519397',
#   'temperature': 73},
#  {'date': Timestamp('2012-11-17 00:00:00'),
#   'precipitation': 0.01,
#   'station_name': 'USC00519397',
#   'temperature': 74},
#  {'date': Timestamp('2012-11-18 00:00:00'),
#   'precipitation': 0.03,
#   'station_name': 'USC00519397',
#   'temperature': 76},
#  {'date': Timestamp('2012-11-19 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2012-11-20 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 75},
#  {'date': Timestamp('2012-11-21 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 71},
#  {'date': Timestamp('2012-11-22 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 69},
#  {'date': Timestamp('2012-11-23 00:00:00'),
#   'precipitation': 0.0,
#   'station_name': 'USC00519397',
#   'temperature': 71},
#  {'date': Timestamp('2012-11-24 00:00:00'),
#   'precipitation': 0.02,
#   'station_name': 'USC00519397',
#   'temperature': 69},
#  ...]

# %%
# Use MetaData from SQLAlchemy to reflect the tables
metadata = MetaData(bind=engine)
metadata.reflect()

# %%
# station_table = sqlalchemy.Table('station', metadata, autoload=True)
# measurement_table = sqlalchemy.Table('measurement', metadata, autoload=True)

# %%
# conn.execute(station_table.insert(), stations_dict)

# %%
# conn.execute("select * from station limit 5").fetchall()

# %%
# measures_objects = conn.execute(measurement_table.insert(), measures_dict)

# %%
# conn.execute("select * from measurement limit 5").fetchall()

# %%
station_obj = [station(station_name=stations_dict[i]['station_name'],
                       location_name=stations_dict[i]['location_name'],
                       latitude=stations_dict[i]['latitude'],
                       longitude=stations_dict[i]['longitude'],
                       elevation=stations_dict[i]['elevation']
                      ) for i in range(0,len(stations_dict))
              ]
station_obj
# Out:
# [<station('USC00519397', 'WAIKIKI 717.2, HI US')>,
#  <station('USC00513117', 'KANEOHE 838.1, HI US')>,
#  <station('USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US')>,
#  <station('USC00517948', 'PEARL CITY, HI US')>,
#  <station('USC00518838', 'UPPER WAHIAWA 874.3, HI US')>,
#  <station('USC00519523', 'WAIMANALO EXPERIMENTAL FARM, HI US')>,
#  <station('USC00519281', 'WAIHEE 837.5, HI US')>,
#  <station('USC00511918', 'HONOLULU OBSERVATORY 702.2, HI US')>,
#  <station('USC00516128', 'MANOA LYON ARBO 785.2, HI US')>]

# %%
measurement_object = [measurement(station_name = measures_dict[i]['station_name'],
                                  date = measures_dict[i]['date'],
                                  precipitation = measures_dict[i]['precipitation'],
                                  temperature = measures_dict[i]['temperature']
                                 ) for i in range(0, len(measures_dict))
                     ]
measurement_object
# Out:
# [<measure('USC00519397', Timestamp('2010-01-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-01-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-01-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-01-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-01-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-01-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-01-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-01-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-01-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-01-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-01-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-01-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-01-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-01-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-01-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-01-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-01-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-01-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-01-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-01-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-01-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-01-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-01-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-01-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-01-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-01-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-01-30 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-01-31 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-02-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-02-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-02-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-02-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-02-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-02-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-02-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-02-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-02-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-02-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-02-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-02-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-02-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-02-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-02-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-02-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-02-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-02-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-02-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-02-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-02-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-02-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-02-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-02-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-03-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-03-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-03-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-03-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-03-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-03-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-03-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-03-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-03-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-03-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-03-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-03-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-03-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-03-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-03-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-03-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-03-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-03-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-03-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-03-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-03-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-03-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-03-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-03-29 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-03-30 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-03-31 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-04-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-04-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-04-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-04-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-04-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-04-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-04-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-04-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-04-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-04-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-04-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-04-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-04-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-04-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-04-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-04-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-04-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-04-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-04-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-04-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-04-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-04-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-04-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-04-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-04-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-04-30 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-05-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-05-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-05-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-05-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-05-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-05-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-05-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-05-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-05-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-05-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-05-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-05-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-05-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-05-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-05-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-05-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-05-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-05-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-05-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-05-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-05-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-05-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-05-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-05-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-05-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-05-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-05-29 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-05-30 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-05-31 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-29 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-06-30 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-07-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-07-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-07-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-07-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-07-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-07-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-07-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-07-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-07-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-07-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-07-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-07-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-07-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-07-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-07-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-07-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-07-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-07-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-07-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-07-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-07-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-07-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-07-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-07-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-07-29 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-07-30 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-07-31 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-29 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-30 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-08-31 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-09-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-09-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-09-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-09-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-09-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-09-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-09-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-09-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-09-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-09-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-09-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-09-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-09-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-09-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-09-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-09-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-09-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-09-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-09-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-09-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-09-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-09-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-09-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-09-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-09-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-09-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-09-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-09-29 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-09-30 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-29 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-30 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-10-31 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-11-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-11-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-11-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-11-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-11-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-11-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-11-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-11-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-11-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-11-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-11-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-11-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-11-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-11-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-11-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-11-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-11-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-11-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-11-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-11-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-11-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-11-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-11-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-11-29 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-11-30 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-12-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-12-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-12-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-12-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-12-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-12-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-12-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-12-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-12-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-12-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-12-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-12-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-12-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-12-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-12-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-12-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-12-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-12-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-12-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-12-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-12-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-12-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-12-29 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-12-30 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2010-12-31 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-01-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-01-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-01-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-01-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-01-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-01-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-01-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-01-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-01-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-01-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-01-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-01-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-01-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-01-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-01-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-01-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-01-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-01-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-01-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-01-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-01-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-01-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-01-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-01-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-01-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-01-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-01-29 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-01-30 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-01-31 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-02-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-02-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-02-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-02-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-02-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-02-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-02-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-02-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-02-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-02-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-02-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-02-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-02-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-02-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-02-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-02-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-02-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-02-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-02-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-02-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-02-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-02-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-02-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-02-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-02-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-03-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-03-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-03-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-03-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-03-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-03-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-03-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-03-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-03-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-03-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-03-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-03-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-03-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-03-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-03-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-03-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-03-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-03-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-03-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-03-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-03-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-03-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-03-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-03-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-03-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-03-30 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-03-31 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-04-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-04-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-04-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-04-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-04-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-04-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-04-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-04-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-04-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-04-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-04-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-04-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-04-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-04-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-04-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-04-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-04-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-04-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-04-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-04-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-04-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-04-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-04-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-04-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-04-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-04-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-04-29 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-04-30 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-29 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-30 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-05-31 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-06-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-06-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-06-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-06-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-06-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-06-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-06-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-06-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-06-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-06-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-06-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-06-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-06-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-06-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-06-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-06-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-06-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-06-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-06-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-06-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-06-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-06-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-06-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-06-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-06-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-06-29 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-29 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-30 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-07-31 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-29 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-30 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-08-31 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-09-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-09-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-09-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-09-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-09-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-09-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-09-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-09-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-09-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-09-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-09-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-09-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-09-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-09-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-09-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-09-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-09-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-09-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-09-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-09-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-09-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-09-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-09-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-09-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-09-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-09-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-09-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-29 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-30 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-10-31 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-29 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-11-30 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-29 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-30 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2011-12-31 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-01-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-01-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-01-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-01-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-01-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-01-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-01-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-01-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-01-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-01-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-01-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-01-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-01-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-01-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-01-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-01-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-01-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-01-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-01-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-01-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-01-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-01-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-01-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-01-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-01-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-01-29 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-01-30 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-01-31 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-02-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-02-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-02-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-02-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-02-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-02-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-02-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-02-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-02-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-02-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-02-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-02-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-02-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-02-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-02-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-02-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-02-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-02-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-02-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-02-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-02-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-02-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-02-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-02-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-02-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-02-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-02-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-02-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-02-29 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-29 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-30 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-03-31 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-29 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-04-30 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-29 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-30 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-05-31 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-29 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-06-30 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-29 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-30 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-07-31 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-29 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-30 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-08-31 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-29 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-09-30 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-24 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-25 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-26 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-27 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-28 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-29 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-30 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-10-31 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-11-01 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-11-02 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-11-03 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-11-04 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-11-05 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-11-06 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-11-07 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-11-08 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-11-09 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-11-10 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-11-11 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-11-12 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-11-13 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-11-14 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-11-15 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-11-16 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-11-17 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-11-18 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-11-19 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-11-20 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-11-21 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-11-22 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-11-23 00:00:00'))>,
#  <measure('USC00519397', Timestamp('2012-11-24 00:00:00'))>,
#  ...]

# %%
session = Session(bind=engine)

# %%
session.rollback()
session.bulk_save_objects(station_obj)
session.bulk_save_objects(measurement_object)

session.commit()

# %%
conn.close()
engine.dispose()
